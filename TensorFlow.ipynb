# %% [markdown]
# create TensorFlow.ipynb

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2025-11-13 16:24:09.952751: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def   c_to_f(c):
  return c * 1.8 +32

# %%
Cs=[0,1,4,12,30,45,100,105,90,77,-40,-10,8,15,22,38]
Fs=[]

for i in Cs:
  f =c_to_f(i)
  Fs.append(f)

# %%
Fs

# %%
import tensorflow as tf
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])

# %%
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])
model.compile(loss='mse' , optimizer=tf.keras.optimizers.Adam(learning_rate=0.01))

# %%
import numpy as np

Cs_np = np.array(Cs)
Fs_np = np.array(Fs)

history = model.fit(Cs_np , Fs_np, epochs=800)

# %%
model.get_weights()

# %%
# !git add .
# !git commit -m "Update from Google Colab to git"
# !git push
