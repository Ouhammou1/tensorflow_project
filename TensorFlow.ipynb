# %% [markdown]
# create TensorFlow.ipynb

# %%
# data-->

# "https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip"

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# 2.18.0

# %%
def   c_to_f(c):
  return c * 1.8 +32

# %%
Cs=[0,1,4,12,30,45,100,105,90,77,-40,-10,8,15,22,38]
Fs=[]

for i in Cs:
  f =c_to_f(i)
  Fs.append(f)

# %%
Fs
# Out:
# [32.0,
#  33.8,
#  39.2,
#  53.6,
#  86.0,
#  113.0,
#  212.0,
#  221.0,
#  194.0,
#  170.6,
#  -40.0,
#  14.0,
#  46.4,
#  59.0,
#  71.6,
#  100.4]

# %%
import tensorflow as tf
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-11-15 11:29:58.319277: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])
model.compile(loss='mse' , optimizer=tf.keras.optimizers.Adam(learning_rate=0.1))

# %%
import numpy as np

Cs_np = np.array(Cs)
Fs_np = np.array(Fs)

history = model.fit(Cs_np , Fs_np, epochs=700)
# Out:
# Epoch 1/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 819ms/step - loss: 8085.1553
# Epoch 2/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 7213.2979
# Epoch 3/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6396.9268
# Epoch 4/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 5636.8711
# Epoch 5/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 4933.7500
# Epoch 6/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 4287.9092
# Epoch 7/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 3699.3994
# Epoch 8/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 3167.9480
# Epoch 9/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2692.9087
# Epoch 10/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2273.2400
# Epoch 11/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1907.4712
# Epoch 12/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1593.6846
# Epoch 13/700
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1329.5005
# Epoch 14/700
# ...

# %%
model.get_weights()
# Out:
# [array([[1.821617]], dtype=float32), array([30.185469], dtype=float32)]

# %%
import os
import tensorflow as tf
import shutil
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
import os

# List all files in the dataset folder
dataset_path = '/kaggle/input/data-cat-dig/PetImages'
print("Dataset path:", dataset_path)
print("Files in dataset:", os.listdir(dataset_path))
# Out:
# Dataset path: /kaggle/input/data-cat-dig/PetImages
# Files in dataset: ['Dog', 'Cat']

# %%
data_path = '/kaggle/input/data-cat-dig/PetImages'
dog_path = os.path.join(data_path , 'Dog')
cat_path = os.path.join(data_path , 'Cat')

print(dog_path)
print(cat_path)
# Out:
# /kaggle/input/data-cat-dig/PetImages/Dog
# /kaggle/input/data-cat-dig/PetImages/Cat

# %%
def clean(path):
    images = os.listdir(path)
    for image in images:
        if os.path.getsize(os.path.join(path , image)) == 0 or image.split('.')[len(image.split('.')) -1] != 'jpg':
            images.remove(image)
    return images

# %%
dogs = clean(dog_path)
cats = clean(cat_path)

# %%
# print(len(dogs))
# os.listdir(dog_path)
# dogs

# %%
# WORKING_DIR = "/kaggle/working/PetImages"

# if not os.path.exists(WORKING_DIR):
#     shutil.copytree("/kaggle/input/data-cat-dig/PetImages", WORKING_DIR)

# data_path = WORKING_DIR

# %%
# def  train_validation_dirs(dir_name , data  , SPLIT_SIZE=0.7 , data_path = data_path , data_length = 7000 ):
#     training_lenght = round(SPLIT_SIZE * data_length)
    
#     train_set = data[0:training_lenght]
#     val_set = data[training_lenght : data_length]


#     os.makedirs(os.path.join(data_path , 'training' , dir_name))
#     os.makedirs(os.path.join(data_path , 'validation' , dir_name))

#     for image in train_set:
#         shutil.copyfile(os.path.join(data_path , dir_name , image), os.path.join(data_path , 'training' , dir_name , image))
            
#     for image in val_set:
#         shutil.copyfile(os.path.join(data_path , dir_name , image), os.path.join(data_path , 'validation' , dir_name , image))

# %%
# train_validation_dirs('Dog' , dogs)
# train_validation_dirs('Cat' , dogs)



# # print(os.makedirs(os.path.join(data_path , 'training' , 'dir_name')))

# %%
import os
import shutil

WORKING_DIR = "/kaggle/working/PetImages"

if not os.path.exists(WORKING_DIR):
    shutil.copytree("/kaggle/input/data-cat-dig/PetImages", WORKING_DIR)

data_path = WORKING_DIR

def train_validation_dirs(dir_name, data, SPLIT_SIZE=0.7, data_path=data_path, data_length=7000):
    training_length = round(SPLIT_SIZE * data_length)
    
    train_set = data[0:training_length]
    val_set = data[training_length:data_length]

    os.makedirs(os.path.join(data_path, 'training', dir_name), exist_ok=True)
    os.makedirs(os.path.join(data_path, 'validation', dir_name), exist_ok=True)

    for image in train_set:
        shutil.copyfile(
            os.path.join(data_path, dir_name, image),
            os.path.join(data_path, 'training', dir_name, image)
        )
            
    for image in val_set:
        shutil.copyfile(
            os.path.join(data_path, dir_name, image),
            os.path.join(data_path, 'validation', dir_name, image)
        )

# %%
train_validation_dirs('Dog' , dogs)
train_validation_dirs('Cat' , dogs)



folder_path = "/kaggle/working/PetImages/training/Dog"
folder_path1 = "/kaggle/working/PetImages/training/Cat"


if os.path.exists(folder_path) and os.path.exists(folder_path1):
    print("exist ")
else:
    print("not exist ")

print(os.listdir("/kaggle/working/PetImages/training"))
print(os.listdir("/kaggle/working/PetImages/validation"))
# Out:
# exist
# ['Dog', 'Cat']
# ['Dog', 'Cat']

# %%
train_generator = ImageDataGenerator(rescale= 1/255)
train_generator = train_generator.flow_from_directory(
    directory = os.path.join(data_path , 'training'),
    shuffle=True,
    class_mode= 'binary',
    target_size = (150 , 150),
    batch_size=100
)
# Out:
# Found 9800 images belonging to 2 classes.

# %%
print(train_generator)

# %%
validation_generator = ImageDataGenerator(rescale= 1/255)
validation_generator = validation_generator.flow_from_directory(
    directory = os.path.join(data_path , 'validation'),
    shuffle=True,
    class_mode= 'binary',
    target_size = (150 , 150),
    batch_size=100
)
# Out:
# Found 4200 images belonging to 2 classes.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(16 , (3,3) , activation='relu' , input_shape=(150,150,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32 , (3,3) ,activation='relu') ,
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64 , (3,3) ,activation='relu') ,
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense( 1, activation='sigmoid')

])

# %%
model.compile(optimizer='adam',
             loss='binary_crossentropy',
              metrics=['accuracy']
             )

# %%
history = model.fit(train_generator,
                    epochs=10,
                    verbose=1,
                    validation_data=validation_generator)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 85/98 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.5540 - loss: 0.6790
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5622 - loss: 0.6744
